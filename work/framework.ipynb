# %%
# %matplotlib inline
# %matplotlib notebook

from math import *

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm
from scipy.stats import gaussian_kde

# %%
with open('./func.out') as f:
    exec(f.read())
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
with open('./func.out') as f:
    exec(f.read())

plt.figure()
plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.boxplot([_0, _1, _2])

plt.figure()
ax = plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.boxplot([_3, _4, _5])

plt.figure()
ax = plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.boxplot([_6, _7, _8])

plt.figure()
ax = plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
plt.boxplot([_1, _4, _7])
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# {'boxes': [<matplotlib.lines.Line2D at 0x7fdf4c2929e8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fdf4c2a0ac8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fdf4bafc940>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fdf4c475358>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fdf4c292b70>,
# ...
#   <matplotlib.lines.Line2D at 0x7fdf4bf2b898>]}

# %%
with open('./func.out') as f:
    exec(f.read())
    
plt.figure()

data = _4
density = gaussian_kde(data)
len = max(_4) - min(_4)
xs = np.linspace(min(_4) - 0.1 * len, max(_4) + 0.1 * len, 1000)
density.covariance_factor = lambda : .03
density._compute_covariance()
plt.plot(xs,density(xs))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
with open('./func.out') as f:
    exec(f.read())
# Out:
# <img src="data:image/png;base64,...">

# %%
with open('./func.out') as f:
    exec(f.read())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
with open('./func_mem.out') as f:
    exec(f.read())
# Out:
# <img src="data:image/png;base64,..." width="640">
