_1.scatter(_12, _13, color='r')
# Out:
# _0 = plt.figure()
# _0.suptitle('')
# _1 = _0.gca()
# _2 = [-0.917270163,-0.8818134043,-0.8741058496,-0.8824690801,-0.8990043537,-0.91891348,-0.9396951817,-0.9602094549,-0.9799672693,-0.9987516892,-1.016461054,-1.033052426,-1.048520158,-1.062884176,-1.076182037,-1.088462626,-1.099781516,-1.110197569,-1.119770509,-1.12855926,-1.196225688,-1.226526135,-1.205956146,-1.208053448,-1.20803792,]
# _3 = [3.132347553,3.107353652,3.100670866,3.103444965,3.11007956,3.11746989,3.12424735,3.130002661,3.134729661,3.138543451,3.141574278,3.14393844,3.145734618,3.147045737,3.147941772,3.14848199,3.148716899,3.148689832,3.148438208,3.147994553,2.885520868,3.020696855,3.052621472,3.056286243,3.056329664,]
# _1.plot(_2, _3)
# ...

# %%
with open('../func.out') as f:
    exec(f.read())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
with open('../func_backup_real.out') as f:
    exec(f.read())

def plot(xs, ys):
    plt.scatter(xs[0], ys[0], color='b')
    plt.scatter(xs[1], ys[1], color='r')
    plt.plot(xs, ys, 'b')

xs, ys = [], []
with open('../a.out', 'r') as f:
    for i in f:
        vals = i.strip().split()
        if vals:
            x, y = vals
            xs.append(float(x))
            ys.append(float(y))
        else:
            plot(xs, ys)
            xs, ys = [], []
    if xs:
        plot(xs, ys)
        xs, ys = [], []
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
with open('../func_backup_real.out') as f:
    exec(f.read())

def plot(xs, ys):
    plt.scatter(xs[0], ys[0], color='b')
    plt.scatter(xs[1], ys[1], color='r')
    plt.plot(xs, ys, 'b')

xs, ys = [], []
with open('../a.out', 'r') as f:
    for i in f:
        vals = i.strip().split()
        if vals:
            x, y = vals
            xs.append(float(x))
            ys.append(float(y))
        else:
            plot(xs, ys)
            xs, ys = [], []
    if xs:
        plot(xs, ys)
        xs, ys = [], []
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
with open('../func_backup_real.out') as f:
    exec(f.read())

def plot(xs, ys):
    plt.scatter(xs[:-1], ys[:-1], color='b')
    plt.scatter(xs[-1], ys[-1], color='r')
    plt.plot(xs, ys, 'b')

xs, ys = [], []
with open('../a.out', 'r') as f:
    for i in f:
        vals = i.strip().split()
        if vals:
            x, y = vals
            xs.append(float(x))
            ys.append(float(y))
        else:
            plot(xs, ys)
            xs, ys = [], []
    if xs:
        plot(xs, ys)
        xs, ys = [], []
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
with open('../func.out') as f:
    exec(f.read())
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
with open('../func.out') as f:
    exec(f.read())
print(np.argmin(_3))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0
