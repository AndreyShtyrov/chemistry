# %%
# %matplotlib inline
# %matplotlib notebook

from math import *

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm
from scipy.stats import gaussian_kde

# %%
with open('./func.out') as f:
    exec(f.read())
    
data = _4
density = gaussian_kde(data)
xs = np.linspace(0,8,200)
density.covariance_factor = lambda : .1
density._compute_covariance()
plt.plot(xs,density(xs))
plt.show()
    
plt.figure()
plt.hist(_4)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (array([ 2520.,     4.,     0.,     6.,    30.,   121.,  3261.,  1220.,
#           864.,   102.]),
#  array([  2.86807143e-11,   1.98827235e-02,   3.97654470e-02,
#           5.96481706e-02,   7.95308941e-02,   9.94136176e-02,
#           1.19296341e-01,   1.39179065e-01,   1.59061788e-01,
#           1.78944512e-01,   1.98827235e-01]),
#  <a list of 10 Patch objects>)

# %%
with open('./func.out') as f:
    exec(f.read())
# Out:
# <img src="data:image/png;base64,...">

# %%
with open('./func.out') as f:
    exec(f.read())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
with open('./func_mem.out') as f:
    exec(f.read())
# Out:
# <img src="data:image/png;base64,..." width="640">
