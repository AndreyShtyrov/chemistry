# %%
# %matplotlib inline
# %matplotlib notebook

from math import *

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm
from scipy.stats import gaussian_kde

# %%
with open('./func.out') as f:
    exec(f.read())
# Out:
# _0 = plt.figure()
# _0.suptitle('distance space false')
# _1 = _0.gca()
# _2 = plt.figure()
# _2.suptitle('distance space true')
# _3 = _2.gca()
# _4 = [-3.106573639,-3.115686098,]
# _5 = [-0.1030747039,-0.1071387106,]
# _1.plot(_4, _5, label=0)
# _6 = [-3.106573639,-3.115686098,]
# _7 = [-0.1030747039,-0.1071387106,]
# _3.plot(_6, _7, label=0)
# _8 = plt.figure()
# _8.suptitle('values 0')
# _9 = _8.gca()
# _10 = [0,1,]
# _11 = [-78.15990408,-78.15942866,]
# _9.plot(_10, _11, label='')
# _12 = plt.figure()
# _12.suptitle('grads  0')
# _13 = _12.gca()
# _14 = [0,1,]
# _15 = [0.0703144263,0.08219325076,]
# _13.plot(_14, _15, label='')
# _16 = [-3.106584971,-3.11569545,]
# _17 = [-0.1030772761,-0.1071409313,]
# _1.plot(_16, _17, label=4)
# _18 = [-3.106584971,-3.11569545,]
# _19 = [-0.1030772761,-0.1071409313,]
# _3.plot(_18, _19, label=4)
# _20 = plt.figure()
# _20.suptitle('values 4')
# _21 = _20.gca()
# _22 = [0,1,]
# _23 = [-78.15990405,-78.15942864,]
# _21.plot(_22, _23, label='')
# _24 = plt.figure()
# _24.suptitle('grads  4')
# _25 = _24.gca()
# _26 = [0,1,]
# _27 = [0.07031329055,0.08219241707,]
# _25.plot(_26, _27, label='')
# _28 = [-3.072014121,-3.073629195,]
# _29 = [-0.09190487487,-0.09398298296,]
# _1.plot(_28, _29, label=2)
# _30 = [-3.072014121,-3.073629195,]
# _31 = [-0.09190487487,-0.09398298296,]
# _3.plot(_30, _31, label=2)
# _32 = plt.figure()
# _32.suptitle('values 2')
# _33 = _32.gca()
# _34 = [0,1,]
# _35 = [-78.16019289,-78.15989471,]
# _33.plot(_34, _35, label='')
# _36 = plt.figure()
# _36.suptitle('grads  2')
# _37 = _36.gca()
# _38 = [0,1,]
# _39 = [0.03793404617,0.04318231514,]
# _37.plot(_38, _39, label='')
# _40 = [-3.118932799,-3.130444079,]
# _41 = [-0.07190715703,-0.069715046,]
# _1.plot(_40, _41, label=6)
# _42 = [-3.118932799,-3.130444079,]
# _43 = [-0.07190715703,-0.069715046,]
# _3.plot(_42, _43, label=6)
# _44 = plt.figure()
# _44.suptitle('values 6')
# _45 = _44.gca()
# _46 = [0,1,]
# _47 = [-78.15987643,-78.15938175,]
# _45.plot(_46, _47, label='')
# _48 = plt.figure()
# _48.suptitle('grads  6')
# _49 = _48.gca()
# _50 = [0,1,]
# _51 = [0.09559209641,0.112535258,]
# _49.plot(_50, _51, label='')
# _52 = [-3.072013574,-3.073628649,]
# _53 = [-0.09190417618,-0.0939822388,]
# _1.plot(_52, _53, label=1)
# _54 = [-3.072013574,-3.073628649,]
# _55 = [-0.09190417618,-0.0939822388,]
# _3.plot(_54, _55, label=1)
# _56 = plt.figure()
# _56.suptitle('values 1')
# _57 = _56.gca()
# _58 = [0,1,]
# _59 = [-78.16019298,-78.15989481,]
# _57.plot(_58, _59, label='')
# _60 = plt.figure()
# _60.suptitle('grads  1')
# _61 = _60.gca()
# _62 = [0,1,]
# _63 = [0.03793152287,0.04317995897,]
# _61.plot(_62, _63, label='')
# _64 = [-3.106575474,-3.115687549,]
# _65 = [-0.1030757943,-0.107139586,]
# _1.plot(_64, _65, label=3)
# _66 = [-3.106575474,-3.115687549,]
# _67 = [-0.1030757943,-0.107139586,]
# _3.plot(_66, _67, label=3)
# _68 = plt.figure()
# _68.suptitle('values 3')
# _69 = _68.gca()
# _70 = [0,1,]
# _71 = [-78.15990409,-78.15942868,]
# _69.plot(_70, _71, label='')
# _72 = plt.figure()
# _72.suptitle('grads  3')
# _73 = _72.gca()
# _74 = [0,1,]
# _75 = [0.07031394045,0.08219278378,]
# _73.plot(_74, _75, label='')
# _76 = [-3.106587571,-3.115697604,]
# _77 = [-0.1030762215,-0.1071400004,]
# _1.plot(_76, _77, label=5)
# _78 = [-3.106587571,-3.115697604,]
# _79 = [-0.1030762215,-0.1071400004,]
# _3.plot(_78, _79, label=5)
# _80 = plt.figure()
# _80.suptitle('values 5')
# _81 = _80.gca()
# _82 = [0,1,]
# _83 = [-78.15990406,-78.15942864,]
# _81.plot(_82, _83, label='')
# _84 = plt.figure()
# _84.suptitle('grads  5')
# _85 = _84.gca()
# _86 = [0,1,]
# _87 = [0.0703143772,0.08219329503,]
# _85.plot(_86, _87, label='')

# %%
with open('./func.out') as f:
    exec(f.read())

# %%
with open('./func.out') as f:
    exec(f.read())
    
plt.figure()

data = _4
density = gaussian_kde(data)
len = max(_4) - min(_4)
xs = np.linspace(min(_4) - 0.1 * len, max(_4) + 0.1 * len, 1000)
density.covariance_factor = lambda : .03
density._compute_covariance()
plt.plot(xs,density(xs))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
