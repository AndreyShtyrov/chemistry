# %%
# %matplotlib inline
# %matplotlib notebook

from math import *

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm

# %%
with open('../func.out') as f:
    exec(f.read())
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
with open('../func.out') as f:
    exec(f.read())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def split_all(file):
    with open(file, 'r') as f:
        for line in f:
            yield from line.split()

def next_int(file_generator):
    return int(next(file_generator))
    
def next_float(file_generator):
    return float(next(file_generator))
    
    
def read_matrix(inp):
    n, m = next_int(inp), next_int(inp)
    vals = np.zeros((n, m))
    for i in range(n):
        for j in range(m):
            vals[i, j] = next_float(inp)
    return vals

N = 500
f = split_all('../func.out')
# a = read_matrix(f)
# print(a.shape)

# fig = plt.figure()
# ax = fig.gca(projection='3d')
# ax.plot_surface(a[:, 0].reshape(N, -1), a[:, 1].reshape(N, -1), a[:, 2].reshape(N, -1), cmap=cm.coolwarm)

aas = []
for i in range(10):
    aas.append(read_matrix(f))
paths = []
for i in range(10):
    paths.append(read_matrix(f))

for a, path in zip(aas, paths):
    fig = plt.figure()
    plt.plot(a[:, 0], a[:, 1], label='value')
    plt.plot(a[:, 0], a[:, 2], label='grad')
    plt.legend()



    plt.plot(path[:, 0], path[:, 1])
    plt.scatter(path[:, 0], path[:, 1], s=2)
    
    for i in range(1, len(path)):
        print(path[i, 0] - path[i, 1])
    
    break
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.66954564
# 0.66471766
# 0.65989887
# 0.65509129
# 0.65029593
# 0.64551179
# 0.64074088
# 0.63598121
# 0.63123577
# 0.62650359
# 0.62178466
# 0.61708
# 0.6123906
# 0.60771548
# 0.60305664
# 0.59841208
# 0.59378481
# 0.58917283
# 0.58457816
# 0.58000079
# 0.57544073
# 0.57089699
# 0.56637256
# 0.56186546
# 0.55737768
# 0.55290823
# 0.54845812
# 0.54402734
# 0.5396159
# 0.5352238
# 0.53085305
# 0.52650164
# 0.52217159
# 0.51786188
# 0.51357353
# 0.50930554
# 0.5050599
# 0.50083563
# 0.49663271
# 0.49245216
# 0.48829396
# 0.48415814
# 0.48004467
# 0.47595357
# 0.47188584
# 0.46784047
# 0.46381846
# 0.45981982
# 0.45584355
# 0.45189164
# 0.44796309
# 0.44405791
# 0.44017709
# 0.43631964
# 0.43248654
# 0.4286768
# 0.42489143
# 0.42112941
# 0.41739275
# 0.41367944
# 0.40999048
# 0.40632688
# 0.40268662
# 0.39907072
# 0.39547916
# 0.39191294
# 0.38837007
# 0.38485253
# 0.38135833
# 0.37788947
# 0.37444494
# 0.37102374
# 0.36762787
# ...
